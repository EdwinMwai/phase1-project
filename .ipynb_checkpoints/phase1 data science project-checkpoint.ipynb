# %% [markdown]
# ## PHASE ONE DATA SCIENCE PROJECT

# %% [markdown]
# ### Multivariate Analysis I (Exploratory Data Analysis) - Exercise 1

# %% [markdown]
# ###### IMPORTING LIBRARIES

# %% [markdown]
# The following is a list of all the libraries that I will need in this project. I may need more libraries but these will get me started.

# %%
#Load the libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import sqlite3

# %% [markdown]
# ## exploring and cleaning bom.movie gross data set

# %%
# import bom.movie_gross.csv as df
bom_movie_gross = pd.read_csv('bom.movie_gross.csv/bom.movie_gross.csv')

# display the number of columns and rows
bom_movie_gross.shape
# Out:
# (3387, 5)

# %% [markdown]
# The data frame above contains 3387 rows and 5 columns

# %%
# preview the first five rows of the data set

bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# understanding the type of data types found in this dataframe
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#displays random group of 10 rows within dataset
bom_movie_gross.sample(10)
# Out:
#                           title  studio  domestic_gross foreign_gross  year
# 599        Texas Killing Fields   Anch.         45500.0        912000  2011
# 2812  Ghost in the Shell (2017)    Par.      40600000.0     129199999  2017
# 3307                   Oh Lucy!      FM        375000.0           NaN  2018
# 239                     Leaving     IFC        176000.0        893000  2010
# 981                 Chasing Ice      SD       1300000.0           NaN  2012
# 28                 Knight & Day     Fox      76400000.0     185500000  2010
# 1103    4:44: Last Day on Earth     IFC         17800.0           NaN  2012
# 2336          X-Men: Apocalypse     Fox     155400000.0     388500000  2016
# 859                  The Master   Wein.      16399999.0      11900000  2012
# 1468             Paradise: Hope  Strand          6700.0           NaN  2013

# %%
# finding out if there is any missing value
bom_movie_gross.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# After sampling the data i realized that there are some missing values. I decided to drop the entire column of foreign_gross because the same data can be found by feature engneering of in tn_movie budget.

# %%
    bom_movie_gross.dropna(subset=['studio', 'domestic_gross'], inplace=True)
    
    bom_movie_gross.drop('foreign_gross', axis=1, inplace=True)

# %%
bom_movie_gross.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# year              0
# dtype: int64

# %%
bom_movie_gross.groupby('year',).sum().sort_values(by = 'year', ascending = True).plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## understanding  rt.movie_info data set

# %%
# import rt_movie_info.tsv as df
rt_movie_info = pd.read_table('rt.movie_info.tsv/rt.movie_info.tsv')

# display the number of columns and rows
rt_movie_info.shape
# Out:
# (1560, 12)

# %%
# preview the first five rows of the data set

rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
# understanding the type of data types found in this dataframe
rt_movie_info.dtypes
# Out:
# id               int64
# synopsis        object
# rating          object
# genre           object
# director        object
# writer          object
# theater_date    object
# dvd_date        object
# currency        object
# box_office      object
# runtime         object
# studio          object
# dtype: object

# %%
#displays random group of 10 rows within dataset
rt_movie_info.sample(10)
# Out:
#         id                                           synopsis rating  \
# 574    744  On a flight home to Chicago for a family weddi...  PG-13
# 346    452  The stars have aligned in an ominous sign, and...     PG
# 1296  1674  "I don't think most people really understood t...     NR
# 990   1283  Historian David Sampliner and musician Tim Nac...     NR
# 196    259  One of history's most shocking horrors returns...     NR
# 533    695  Edward G. Robinson plays orchid-loving gangste...     NR
# 173    227  A gifted young singer-songwriter recruits the ...     PG
# 760    978  'THX 1138' is a chilling look at a 25th-centur...     PG
# 895   1158  In this drama, an international crisis is spaw...     NR
# 186    247  Based on a popular British television drama, t...     NR
#
#                                                   genre  \
# 574                                      Comedy|Romance
# 346   Action and Adventure|Animation|Science Fiction...
# 1296                       Documentary|Special Interest
# 990                        Documentary|Special Interest
# 196                   Drama|Horror|Mystery and Suspense
# 533          Action and Adventure|Classics|Comedy|Drama
# 173            Comedy|Drama|Musical and Performing Arts
# 760                   Drama|Science Fiction and Fantasy
# 895     Action and Adventure|Drama|Mystery and Suspense
# 186           Art House and International|Drama|Romance
#
#                                          director  \
# 574                                  John Burgess
# 346                                  Kevin Munroe
# 1296                              Leslie Cockburn
# 990   Tim Nackashi|David Sampliner|Eric DelaBarre
# 196                                           NaN
# 533                                   Lloyd Bacon
# 173                                    Todd Graff
# 760                                  George Lucas
# 895                                           NaN
# 186                                           NaN
#
#                                writer  theater_date      dvd_date currency  \
# 574                     Dode Levenson   Feb 6, 2015   Feb 9, 2015      NaN
# 346                      Kevin Munroe  Mar 23, 2007   Aug 7, 2007        $
# 1296  Leslie Cockburn|Andrew Cockburn           NaN           NaN      NaN
# 990                               NaN           NaN           NaN      NaN
# 196                         Leif Holt           NaN           NaN      NaN
# 533                               NaN   Jun 7, 1940  Mar 25, 2008      NaN
# 173                               NaN  Aug 14, 2009  Mar 16, 2010        $
# 760         George Lucas|Walter Murch  Mar 11, 1971  Sep 14, 2004      NaN
# 895                   Zenzo Matsumura           NaN           NaN      NaN
# 186                        Ted Willis           NaN           NaN      NaN
#
#       box_office      runtime                 studio
# 574          NaN  100 minutes    Freestyle Releasing
# 346   54,132,596   86 minutes  Warner Bros. Pictures
# 1296         NaN   89 minutes         Argot Pictures
# 990          NaN   58 minutes        New Video Group
# 196          NaN   93 minutes                    NaN
# 533          NaN   91 minutes                    NaN
# 173    5,205,343  111 minutes   Summit Entertainment
# 760          NaN   88 minutes  Warner Bros. Pictures
# 895          NaN  133 minutes                    NaN
# 186          NaN   93 minutes                    NaN

# %%
# understanding the type of data types found in this dataframe
rt_movie_info.isna().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
#removing columns where nearly all data is missing
rt_movie_info = rt_movie_info.dropna(subset = ['synopsis', 'director', 
                               'writer', 'theater_date', 
                               'dvd_date', 'currency', 
                               'box_office', 'studio',
                              'runtime'
                              ], how = 'all')

# %%
#removong some columns that we may not use
rt_movie_info = rt_movie_info.drop(['currency', 'box_office', 'studio' ], axis=1)

# %%
rt_movie_info
# Out:
# 121         R
# 694        PG
# 988     PG-13
# 1263       NR
# 205        PG
# 917         R
# 151     PG-13
# 126        NR
# 791     PG-13
# 1086       NR
# Name: rating, dtype: object

# %% [markdown]
# ## understanding  tmdb.movies.csv data set

# %%
# import tmdb.movies.csv as df
tmdb_movies = pd.read_csv('tmdb.movies.csv/tmdb.movies.csv')

# display the number of columns and rows
tmdb_movies.shape
# Out:
# (26517, 10)

# %%
# preview the first five rows of the data set
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
# understanding the type of data types found in this dataframe
tmdb_movies.dtypes
# Out:
# Unnamed: 0             int64
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
#displays random group of 10 rows within dataset
tmdb_movies.sample(10)
# Out:
#        Unnamed: 0        genre_ids      id original_language  \
# 19325       19325      [53, 10770]  452787                en
# 2450         2450      [10402, 35]  303914                en
# 10180       10180          [10402]  225887                en
# 8821         8821  [18, 10749, 35]  229749                en
# 10882       10882     [18, 27, 53]  259303                en
# 12029       12029             [99]  250745                en
# 25545       25545         [99, 27]  457775                en
# 2496         2496      [16, 10751]   45772                en
# 14334       14334     [28, 35, 80]  268920                en
# 26011       26011             [18]  508729                en
#
#                                           original_title  popularity  \
# 19325                                       The Follower       0.848
# 2450                                       Not Your Time       0.600
# 10180  Portnoy Sheehan MacAlpine Sherinian: Live in T...       0.600
# 8821                                When Calls the Heart       2.259
# 10882                                      The Poisoning       0.600
# 12029                                       Happy Valley       2.309
# 25545                        The Devil and Father Amorth       1.850
# 2496                                     Gnomeo & Juliet      16.408
# 14334                                        Hot Pursuit       9.607
# 26011                                     Broken Ceiling       0.906
#
#       release_date                                              title  \
# 19325   2016-04-17                                       The Follower
# 2450    2010-09-24                                      Not Your Time
# 10180   2013-09-03  Portnoy Sheehan MacAlpine Sherinian: Live in T...
# 8821    2013-10-05                               When Calls the Heart
# 10882   2013-12-24                                      The Poisoning
# 12029   2014-11-14                                       Happy Valley
# 25545   2018-04-20                        The Devil and Father Amorth
# 2496    2011-02-11                                    Gnomeo & Juliet
# 14334   2015-05-08                                        Hot Pursuit
# 26011   2018-02-23                                     Broken Ceiling
#
#        vote_average  vote_count
# 19325           4.3           7
# 2450            1.0           1
# 10180           8.0           1
# 8821            6.9          30
# 10882           3.5           2
# 12029           6.7          25
# 25545           5.3          40
# 2496            5.8        1085
# 14334           5.6        1000
# 26011           6.0           1

# %%
#glimpse of the number of original movie language
tmdb_movies.original_language.value_counts()
# Out:
# original_language
# en    23291
# fr      507
# es      455
# ru      298
# ja      265
#       ...
# bo        1
# si        1
# sl        1
# hz        1
# dz        1
# Name: count, Length: 76, dtype: int64

# %%
# understanding the type of data types found in this dataframe
tmdb_movies.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
tmdb_movies.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
tmdb_movies['genre_ids'].value_counts()
# Out:
# genre_ids
# [99]                       3700
# []                         2479
# [18]                       2268
# [35]                       1660
# [27]                       1145
#                            ...
# [37, 12]                      1
# [10752, 878]                  1
# [28, 53, 10749, 18, 35]       1
# [99, 80, 53, 36]              1
# [10751, 12, 28]               1
# Name: count, Length: 2477, dtype: int64

# %%
tmdb_movies[tmdb_movies['genre_ids']== '[]']
# Out:
#        Unnamed: 0 genre_ids      id original_language  \
# 517           517        []   31059                ru
# 559           559        []  151316                en
# 589           589        []   75828                en
# 689           689        []  150782                en
# 731           731        []  200946                en
# ...           ...       ...     ...               ...
# 26495       26495        []  556601                en
# 26497       26497        []  514045                en
# 26498       26498        []  497839                en
# 26500       26500        []  561932                en
# 26506       26506        []  561861                en
#
#                                original_title  popularity release_date  \
# 517                  Наша Russia: Яйца судьбы       3.867   2010-01-21
# 559                          Shrek’s Yule Log       3.424   2010-12-07
# 589                                   Erratum       3.154   2010-09-16
# 689                       Bikini Frankenstein       2.625   2010-01-18
# 731                                  Weakness       2.451   2010-10-24
# ...                                       ...         ...          ...
# 26495                               Recursion       0.600   2018-08-28
# 26497                      The Portuguese Kid       0.600   2018-02-14
# 26498  The 23rd Annual Critics' Choice Awards       0.600   2018-01-11
# 26500                                     Two       0.600   2018-02-04
# 26506                                    Eden       0.600   2018-11-25
#
#                                         title  vote_average  vote_count
# 517                Nasha Russia: Yaytsa sudby           4.3          25
# 559                          Shrek’s Yule Log           4.7           9
# 589                                   Erratum           6.6           7
# 689                       Bikini Frankenstein           6.0           4
# 731                                  Weakness           4.5           2
# ...                                       ...           ...         ...
# 26495                               Recursion           2.0           1
# 26497                      The Portuguese Kid           2.0           1
# 26498  The 23rd Annual Critics' Choice Awards           2.0           1
# 26500                                     Two           1.0           1
# 26506                                    Eden           0.0           1
#
# [2479 rows x 10 columns]

# %% [markdown]
# ## understanding  tn_movie_budgets data set

# %%
# import tn.movie_budgets.csv as df
tn_movie_budgets = pd.read_csv('tn.movie_budgets.csv/tn.movie_budgets.csv')

# display the number of columns and rows
tn_movie_budgets.shape
# Out:
# (5782, 6)

# %%
# preview the first five rows of the data set
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# understanding the type of data types found in this dataframe
tn_movie_budgets.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
#displays random group of 10 rows within dataset
tn_movie_budgets.sample(10)
# Out:
#       id  release_date                       movie production_budget  \
# 88    89  Nov 23, 2011                        Hugo      $180,000,000
# 4249  50  Jan 20, 2017                       Split        $5,000,000
# 3034  35   Nov 7, 2014    The Theory of Everything       $15,000,000
# 5746  47   Aug 1, 1997       In the Company of Men           $25,000
# 3135  36  Mar 14, 2008                 Funny Games       $15,000,000
# 2184  85  Jan 13, 2012                  Contraband       $25,000,000
# 3845  46  Sep 21, 2001                     Glitter        $8,500,000
# 451   52  Jul 11, 1997                     Contact       $90,000,000
# 3452  53  Oct 19, 2013  Supesu Batorushippu Yamato       $12,000,000
# 2751  52  Nov 24, 1993              The Nutcracker       $19,000,000
#
#      domestic_gross worldwide_gross
# 88      $73,864,507    $180,047,784
# 4249   $138,141,585    $278,964,806
# 3034    $35,893,537    $123,327,692
# 5746     $2,883,661      $2,883,661
# 3135     $1,294,640      $8,200,127
# 2184    $66,528,000     $98,406,855
# 3845     $4,273,372      $4,273,372
# 451    $100,920,329    $165,900,000
# 3452             $0              $0
# 2751     $2,119,994      $2,119,994

# %%
#checking if there is any missing values
tn_movie_budgets.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
#checking if there is any duplicates
tn_movie_budgets.drop_duplicates()
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].str.strip('$')
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].str.lstrip('$')
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].str.lstrip('$')

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0       425,000,000    760,507,625   2,776,345,279
# 1       410,600,000    241,063,875   1,045,663,875
# 2       350,000,000     42,762,350     149,762,350
# 3       330,600,000    459,005,868   1,403,013,963
# 4       317,000,000    620,181,382   1,316,721,747

# %%
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].str.replace(',', '')
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].str.replace(',', '')
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].str.replace(',', '')

# %%
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].astype('int')
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].astype('int')

# %%
from decimal import Decimal
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].apply(lambda x: Decimal(x.replace(',', '')))

# %%
tn_movie_budgets['worldwide_gross']
# Out:
# 0       2776345279
# 1       1045663875
# 2        149762350
# 3       1403013963
# 4       1316721747
#            ...
# 5777             0
# 5778        240495
# 5779          1338
# 5780             0
# 5781        181041
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
tn_movie_budgets['international_sales'] = tn_movie_budgets['worldwide_gross'] -tn_movie_budgets['domestic_gross']

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross worldwide_gross international_sales
# 0          425000000       760507625      2776345279          2015837654
# 1          410600000       241063875      1045663875           804600000
# 2          350000000        42762350       149762350           107000000
# 3          330600000       459005868      1403013963           944008095
# 4          317000000       620181382      1316721747           696540365

# %%
tn_movie_budgets['release_date'] = pd.to_datetime(tn_movie_budgets['release_date'])

# %%
tn_movie_budgets.plot.scatter(x = 'production_budget', y = 'worldwide_gross')
# Out:
# <Axes: xlabel='production_budget', ylabel='worldwide_gross'>

# %%
tn_movie_budgets['profit'] = tn_movie_budgets['worldwide_gross'] -tn_movie_budgets['production_budget']

# %%
tn_movie_budgets.plot.scatter(x = 'production_budget', y = 'profit')
# Out:
# <Axes: xlabel='production_budget', ylabel='profit'>
