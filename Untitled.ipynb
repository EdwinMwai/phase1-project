# %% [markdown]
# ## PHASE ONE DATA SCIENCE PROJECT

# %% [markdown]
# ### Multivariate Analysis I (Exploratory Data Analysis) - Exercise 1

# %% [markdown]
# ###### IMPORTING LIBRARIES

# %% [markdown]
# The following is a list of all the libraries that I will need in this project. I may need more libraries but these will get me started.

# %%
#Load the libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import sqlite3

# %% [markdown]
# ## understanding  bom.movie gross data set

# %%
# import bom.movie_gross.csv as df
bom_movie_gross = pd.read_csv('bom.movie_gross.csv/bom.movie_gross.csv')

# display the number of columns and rows
bom_movie_gross.shape
# Out:
# (3387, 5)

# %%
# preview the first five rows of the data set

bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# understanding the type of data types found in this dataframe
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#displays random group of 10 rows within dataset
bom_movie_gross.sample(10)
# Out:
#                        title  studio  domestic_gross foreign_gross  year
# 782              Cloud Atlas      WB      27100000.0     103400000  2012
# 1506               Neighbors    Uni.     150200000.0     120500000  2014
# 2313       The Iron Ministry   Icar.          3200.0           NaN  2015
# 1515          Into the Woods      BV     128000000.0      85100000  2014
# 821            That's My Boy    Sony      36900000.0      20800000  2012
# 2096   Infinitely Polar Bear     SPC       1400000.0           NaN  2015
# 2135  Somewhere Only We Know      CL        482000.0           NaN  2015
# 703            Love in Space      CL         34800.0           NaN  2011
# 214           Letters to God    Viv.       2800000.0         60300  2010
# 709              Tyrannosaur  Strand         22300.0           NaN  2011

# %%
# finding out if there is any missing value
bom_movie_gross.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# ## understanding  rt.movie_info data set

# %%
# import rt_movie_info.tsv as df
rt_movie_info = pd.read_table('rt.movie_info.tsv/rt.movie_info.tsv')

# display the number of columns and rows
rt_movie_info.shape
# Out:
# (1560, 12)

# %%
# preview the first five rows of the data set

rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
# understanding the type of data types found in this dataframe
rt_movie_info.dtypes
# Out:
# id               int64
# synopsis        object
# rating          object
# genre           object
# director        object
# writer          object
# theater_date    object
# dvd_date        object
# currency        object
# box_office      object
# runtime         object
# studio          object
# dtype: object

# %%
#displays random group of 10 rows within dataset
rt_movie_info.sample(10)
# Out:
#         id                                           synopsis rating  \
# 461    604  Produced in association with the publishers of...      R
# 1331  1722  Former cop Brian O'Conner (Paul Walker) partne...  PG-13
# 1142  1472  Based on a true story, Virginia McKenna portra...     NR
# 830   1075  Just a few years after Psycho made him an inte...     NR
# 1118  1443  John Ripley (Glenn Ford) is the FBI agent call...     NR
# 130    165  The novel of the same name by author Tom Savag...      R
# 1155  1487  In the highly anticipated sequel, which was in...  PG-13
# 914   1182  "Michael Jackson's This Is It" will offer Jack...     PG
# 723    930  Mark Renton (Ewan McGregor), a young man with ...      R
# 1483  1908  The Unearthly Stranger takes a romantic approa...     NR
#
#                                                   genre        director  \
# 461   Documentary|Musical and Performing Arts|Specia...    Kwame Amoaku
# 1331    Action and Adventure|Drama|Mystery and Suspense      Justin Lin
# 1142                         Drama|Mystery and Suspense   Lewis Gilbert
# 830          Art House and International|Classics|Drama  Anatole Litvak
# 1118               Classics|Horror|Mystery and Suspense   Blake Edwards
# 130                         Horror|Mystery and Suspense    Jamie Blanks
# 1155                                     Comedy|Romance       Tim Story
# 914             Documentary|Musical and Performing Arts    Kenny Ortega
# 723                                        Comedy|Drama     Danny Boyle
# 1483                Science Fiction and Fantasy|Romance      John Krish
#
#                                                  writer  theater_date  \
# 461                                                 NaN  Dec 31, 2003
# 1331                                       Chris Morgan  Apr 29, 2011
# 1142  Vernon Harris|Lewis Gilbert|Vernon Gilbert Harris   Sep 8, 1958
# 830                          Peter Viertel|Hugh Wheeler  Dec 12, 1962
# 1118                      Mildred Gordon|Gordon Elliott   Jan 1, 1962
# 130                                                 NaN   Feb 2, 2001
# 1155                                                NaN  Jun 20, 2014
# 914                                                 NaN  Oct 28, 2009
# 723                                          John Hodge  Jul 19, 1996
# 1483                                                NaN           NaN
#
#           dvd_date currency   box_office      runtime  \
# 461    May 4, 2004      NaN          NaN   86 minutes
# 1331   Oct 4, 2011        $  209,805,005  131 minutes
# 1142  May 12, 2009      NaN          NaN  119 minutes
# 830   Jul 26, 2016      NaN          NaN  110 minutes
# 1118  Jun 10, 2003      NaN          NaN  123 minutes
# 130   Jul 24, 2001        $   19,755,422   96 minutes
# 1155  Sep 16, 2014      NaN          NaN  106 minutes
# 914   Jan 26, 2010        $   71,844,424  121 minutes
# 723   Mar 24, 1998      NaN          NaN   93 minutes
# 1483           NaN      NaN          NaN   75 minutes
#
#                                studio
# 461                               NaN
# 1331               Universal Pictures
# 1142                              NaN
# 830                               NaN
# 1118                              NaN
# 130             Warner Bros. Pictures
# 1155                    Sony Pictures
# 914   Sony Pictures/Columbia Pictures
# 723                     Miramax Films
# 1483                              NaN

# %%
# understanding the type of data types found in this dataframe
rt_movie_info.isna().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %% [markdown]
# ## understanding  tmdb.movies.csv data set

# %%
# import tmdb.movies.csv as df
tmdb_movies = pd.read_csv('tmdb.movies.csv/tmdb.movies.csv')

# display the number of columns and rows
tmdb_movies.shape
# Out:
# (26517, 10)

# %%
# preview the first five rows of the data set
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
# understanding the type of data types found in this dataframe
tmdb_movies.dtypes
# Out:
# Unnamed: 0             int64
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
#displays random group of 10 rows within dataset
tmdb_movies.sample(10)
# Out:
#        Unnamed: 0             genre_ids      id original_language  \
# 18597       18597       [35, 18, 10749]  337958                en
# 19793       19793                  [16]  540234                ja
# 15567       15567       [16, 10751, 14]  379559                en
# 18311       18311  [10770, 878, 28, 27]  335409                en
# 21114       21114           [18, 10749]  390056                en
# 21478       21478                    []  425285                en
# 12655       12655           [35, 10402]  370488                en
# 14941       14941         [18, 53, 878]  331592                en
# 23542       23542                  [99]  459249                en
# 25466       25466                  [99]  503646                en
#
#                            original_title  popularity release_date  \
# 18597                  Last Cab to Darwin       1.913   2016-01-10
# 19793                              青い海と少年       0.623   2016-03-15
# 15567                                Soar       1.400   2015-08-25
# 18311  Sharkansas Women's Prison Massacre       2.714   2016-05-03
# 21114                    Rebel in the Rye       7.178   2017-09-15
# 21478                             Halfway       3.517   2017-04-21
# 12655                  Mary Poppins Quits       1.090   2014-07-23
# 14941                           Listening       3.383   2015-09-11
# 23542                             100 Men       0.600   2017-07-08
# 25466                 The Bray Road Beast       1.944   2018-10-01
#
#                                     title  vote_average  vote_count
# 18597                  Last Cab to Darwin           7.1          30
# 19793            The Boy and the Blue Sea           7.0           1
# 15567                                Soar           6.7           9
# 18311  Sharkansas Women's Prison Massacre           5.1          19
# 21114                    Rebel in the Rye           6.9         102
# 21478                             Halfway           6.3           3
# 12655                  Mary Poppins Quits           6.1           7
# 14941                           Listening           5.7          46
# 23542                             100 Men           6.0           2
# 25466                 The Bray Road Beast           6.5           4

# %%
# understanding the type of data types found in this dataframe
tmdb_movies.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %% [markdown]
# ## understanding  tmdb.movies.csv data set

# %%
# import tn.movie_budgets.csv as df
tn_movie_budgets = pd.read_csv('tn.movie_budgets.csv/tn.movie_budgets.csv')

# display the number of columns and rows
tn_movie_budgets.shape
# Out:
# (5782, 6)

# %%
# preview the first five rows of the data set
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# understanding the type of data types found in this dataframe
tn_movie_budgets.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
#displays random group of 10 rows within dataset
tn_movie_budgets.sample(10)
# Out:
#        id  release_date                                 movie  \
# 4678   79   Aug 1, 1986  Friday the 13th Part VI: Jason Lives
# 1649   50  Aug 18, 2000                              The Cell
# 4342   43  Feb 25, 2011               Des Hommes et Des Dieux
# 2085   86  Jan 13, 2012                          Joyful Noise
# 4399  100  Oct 27, 2015                       Running Forever
# 2224   25  Dec 10, 2014                           The Gambler
# 5138   39  Mar 15, 1985                             Def-Con 4
# 936    37  Mar 26, 1999                                  EDtv
# 2084   85   Feb 8, 2008           Welcome Home Roscoe Jenkins
# 718    19  Jan 20, 2012                 Underworld: Awakening
#
#      production_budget domestic_gross worldwide_gross
# 4678        $3,000,000    $19,472,057     $19,472,057
# 1649       $35,000,000    $61,280,963     $85,911,226
# 4342        $5,000,000     $3,954,651     $46,263,525
# 2085       $27,500,000    $30,932,113     $31,157,914
# 4399        $5,000,000             $0              $0
# 2224       $25,000,000    $33,680,992     $38,718,031
# 5138        $1,300,000       $210,904        $210,904
# 936        $60,000,000    $22,508,689     $35,319,689
# 2084       $27,500,000    $42,436,517     $43,607,627
# 718        $70,000,000    $62,321,039    $160,379,930
